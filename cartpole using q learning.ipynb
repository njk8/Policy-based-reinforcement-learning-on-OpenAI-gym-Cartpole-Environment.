# %%
# Q_Learning is a way to measure the reward that we would get when taking a particular action 'a' in a state 's'. 
# It is not only a measurment of the immediate reward but a summation of the entire future reward we would get from 
# consequent actions as well. 
# Q(s,a) = r + Y*max(Q(s',a')); where, r is the immediate reward
# Input will have a state matrix, the output matrix from the Neural Network would be a matrix of how good 
# each action is


import numpy as np
import matplotlib.pyplot as plt
import os
from collections import deque
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
import random

class Agent:
    
    def __init__(self,state_size,action_size):
        
        self.state_size= state_size
        self.action_size = action_size
        self.gamma = 0.95  # discount factor
        self.memory= deque(maxlen=2000)
        
        # exploration vs exploitation Trade off
        # exploration: good in the begining -> helps you to try various random things
        # exploitation: sample good experience from the past(memory)--> good in the end
        
        self.epsilon=1.0  #100 % exploration in the begining
        self.epsilon_decay=0.995
        self.epsilon_min=0.01
        self.learning_rate=0.001
        self.model= self._create_model()
    
    def _create_model(self):
        
        model=Sequential()
        model.add(Dense(24,activation='relu',input_dim=self.state_size))
        model.add(Dense(24,activation='relu'))
        model.add(Dense(self.action_size,activation='linear'))
        model.compile(loss='mse',optimizer=Adam(lr=self.learning_rate))
        return model
    
    
    # We need data to train the neural network, thus we use Replay Buffer Technique to generate data on the fly 
    # and use it for training 
    def remember(self,state,action,reward,next_state,done):
        self.memory.append((state,action,reward,next_state,done))
    
    
    def act(self,state):
        
        # Exploration vs Exploitation
        # sampling according to epsilon greedy method
        
        if np.random.rand()<=self.epsilon:
            return random.randrange(self.action_size)
        else:      ## in else case: ask neural network to give me the suitable action
            return np.argmax(self.model.predict(state)[0])
        
    def train(self,batch_size=32):
        minibatch=random.sample(self.memory,batch_size)
        for state,action,reward,next_state,done in minibatch:
            
            if not done:
                target= reward+ self.gamma*np.max(self.model.predict(next_state)[0])
            else:
                target=reward
            
            target_f = self.model.predict(state)
            target_f[0][action]=target
            
            self.model.fit(state,target_f,epochs=1,verbose=0)
        if self.epsilon > self.epsilon_min:
            
            self.epsilon*=self.epsilon_decay
    def load(self,name):
        self.model.load_weights(name)
        
    def save(self,name):
        self.model.save_weights(name)

# %%
import gym

import numpy as np

env= gym.make('CartPole-v0')

n_episodes = 500


output_dir = "cartpole_model/"

state_size = 4
action_size =2
batch_size = 32

agent = Agent(state_size, action_size) 

done = False  # initialy game is not completed

for e in range(n_episodes): 
    state = env.reset()
    state = np.reshape(state,[1,state_size])  ## state ko reshape kiya (1,4) shape mein
    
    for time in range(500):
        env.render()
        
        action = agent.act(state) #action is 0 or 1
        
        next_state,reward,done,other_info = env.step(action) 
        
        
        reward = reward if not done else -10
        
        next_state = np.reshape(next_state,[1,state_size])
        
        agent.remember(state,action,reward,next_state,done)
        
        state = next_state
        
        if done:
            print("Game Episode :{}/{}, High Score:{},Exploration Rate:{:.2}".format(e,n_episodes,time,agent.epsilon))
            break
            
    if len(agent.memory)>batch_size:
        agent.train(batch_size)
    
   # if e%50==0:
    #    agent.save(output_dir+"weights_"+'{:04d}'.format(e)+".hdf5")
        
print("Deep Q-Learner Model Trained!")
env.close()
# Out:
# Game Episode :0/500, High Score:16,Exploration Rate:1.0
# Game Episode :1/500, High Score:21,Exploration Rate:1.0
# Game Episode :2/500, High Score:24,Exploration Rate:0.99
# Game Episode :3/500, High Score:22,Exploration Rate:0.99
# Game Episode :4/500, High Score:16,Exploration Rate:0.99
# Game Episode :5/500, High Score:22,Exploration Rate:0.98
# Game Episode :6/500, High Score:16,Exploration Rate:0.98
# Game Episode :7/500, High Score:38,Exploration Rate:0.97
# Game Episode :8/500, High Score:9,Exploration Rate:0.97
# Game Episode :9/500, High Score:34,Exploration Rate:0.96
# Game Episode :10/500, High Score:26,Exploration Rate:0.96
# Game Episode :11/500, High Score:21,Exploration Rate:0.95
# Game Episode :12/500, High Score:18,Exploration Rate:0.95
# Game Episode :13/500, High Score:35,Exploration Rate:0.94
# Game Episode :14/500, High Score:10,Exploration Rate:0.94
# Game Episode :15/500, High Score:15,Exploration Rate:0.93
# Game Episode :16/500, High Score:11,Exploration Rate:0.93
# Game Episode :17/500, High Score:13,Exploration Rate:0.92
# Game Episode :18/500, High Score:18,Exploration Rate:0.92
# Game Episode :19/500, High Score:16,Exploration Rate:0.91
# Game Episode :20/500, High Score:29,Exploration Rate:0.91
# Game Episode :21/500, High Score:39,Exploration Rate:0.9
# Game Episode :22/500, High Score:38,Exploration Rate:0.9
# Game Episode :23/500, High Score:12,Exploration Rate:0.9
# Game Episode :24/500, High Score:14,Exploration Rate:0.89
# Game Episode :25/500, High Score:12,Exploration Rate:0.89
# Game Episode :26/500, High Score:20,Exploration Rate:0.88
# Game Episode :27/500, High Score:19,Exploration Rate:0.88
# Game Episode :28/500, High Score:22,Exploration Rate:0.87
# Game Episode :29/500, High Score:52,Exploration Rate:0.87
# Game Episode :30/500, High Score:16,Exploration Rate:0.86
# Game Episode :31/500, High Score:23,Exploration Rate:0.86
# Game Episode :32/500, High Score:23,Exploration Rate:0.86
# Game Episode :33/500, High Score:23,Exploration Rate:0.85
# Game Episode :34/500, High Score:12,Exploration Rate:0.85
# Game Episode :35/500, High Score:13,Exploration Rate:0.84
# Game Episode :36/500, High Score:20,Exploration Rate:0.84
# Game Episode :37/500, High Score:12,Exploration Rate:0.83
# Game Episode :38/500, High Score:19,Exploration Rate:0.83
# Game Episode :39/500, High Score:17,Exploration Rate:0.83
# Game Episode :40/500, High Score:29,Exploration Rate:0.82
# Game Episode :41/500, High Score:35,Exploration Rate:0.82
# Game Episode :42/500, High Score:9,Exploration Rate:0.81
# Game Episode :43/500, High Score:45,Exploration Rate:0.81
# Game Episode :44/500, High Score:13,Exploration Rate:0.81
# Game Episode :45/500, High Score:12,Exploration Rate:0.8
# Game Episode :46/500, High Score:32,Exploration Rate:0.8
# Game Episode :47/500, High Score:48,Exploration Rate:0.79
# Game Episode :48/500, High Score:17,Exploration Rate:0.79
# Game Episode :49/500, High Score:16,Exploration Rate:0.79
# Game Episode :50/500, High Score:11,Exploration Rate:0.78
# Game Episode :51/500, High Score:35,Exploration Rate:0.78
# Game Episode :52/500, High Score:17,Exploration Rate:0.77
# Game Episode :53/500, High Score:44,Exploration Rate:0.77
# Game Episode :54/500, High Score:13,Exploration Rate:0.77
# Game Episode :55/500, High Score:17,Exploration Rate:0.76
# Game Episode :56/500, High Score:15,Exploration Rate:0.76
# Game Episode :57/500, High Score:8,Exploration Rate:0.76
# Game Episode :58/500, High Score:21,Exploration Rate:0.75
# Game Episode :59/500, High Score:16,Exploration Rate:0.75
# Game Episode :60/500, High Score:18,Exploration Rate:0.74
# Game Episode :61/500, High Score:8,Exploration Rate:0.74
# Game Episode :62/500, High Score:12,Exploration Rate:0.74
# Game Episode :63/500, High Score:23,Exploration Rate:0.73
# Game Episode :64/500, High Score:104,Exploration Rate:0.73
# Game Episode :65/500, High Score:8,Exploration Rate:0.73
# Game Episode :66/500, High Score:15,Exploration Rate:0.72
# Game Episode :67/500, High Score:16,Exploration Rate:0.72
# Game Episode :68/500, High Score:32,Exploration Rate:0.71
# Game Episode :69/500, High Score:32,Exploration Rate:0.71
# Game Episode :70/500, High Score:15,Exploration Rate:0.71
# Game Episode :71/500, High Score:20,Exploration Rate:0.7
# Game Episode :72/500, High Score:15,Exploration Rate:0.7
# Game Episode :73/500, High Score:8,Exploration Rate:0.7
# Game Episode :74/500, High Score:10,Exploration Rate:0.69
# Game Episode :75/500, High Score:15,Exploration Rate:0.69
# Game Episode :76/500, High Score:19,Exploration Rate:0.69
# Game Episode :77/500, High Score:25,Exploration Rate:0.68
# Game Episode :78/500, High Score:18,Exploration Rate:0.68
# Game Episode :79/500, High Score:15,Exploration Rate:0.68
# Game Episode :80/500, High Score:16,Exploration Rate:0.67
# Game Episode :81/500, High Score:10,Exploration Rate:0.67
# Game Episode :82/500, High Score:12,Exploration Rate:0.67
# Game Episode :83/500, High Score:44,Exploration Rate:0.66
# Game Episode :84/500, High Score:13,Exploration Rate:0.66
# Game Episode :85/500, High Score:24,Exploration Rate:0.66
# Game Episode :86/500, High Score:40,Exploration Rate:0.65
# Game Episode :87/500, High Score:25,Exploration Rate:0.65
# Game Episode :88/500, High Score:24,Exploration Rate:0.65
# Game Episode :89/500, High Score:12,Exploration Rate:0.64
# Game Episode :90/500, High Score:10,Exploration Rate:0.64
# Game Episode :91/500, High Score:17,Exploration Rate:0.64
# Game Episode :92/500, High Score:7,Exploration Rate:0.63
# Game Episode :93/500, High Score:14,Exploration Rate:0.63
# Game Episode :94/500, High Score:9,Exploration Rate:0.63
# Game Episode :95/500, High Score:28,Exploration Rate:0.62
# Game Episode :96/500, High Score:8,Exploration Rate:0.62
# Game Episode :97/500, High Score:9,Exploration Rate:0.62
# Game Episode :98/500, High Score:20,Exploration Rate:0.61
# Game Episode :99/500, High Score:14,Exploration Rate:0.61
# Game Episode :100/500, High Score:19,Exploration Rate:0.61
# Game Episode :101/500, High Score:29,Exploration Rate:0.61
# Game Episode :102/500, High Score:15,Exploration Rate:0.6
# Game Episode :103/500, High Score:13,Exploration Rate:0.6
# Game Episode :104/500, High Score:8,Exploration Rate:0.6
# Game Episode :105/500, High Score:11,Exploration Rate:0.59
# Game Episode :106/500, High Score:10,Exploration Rate:0.59
# Game Episode :107/500, High Score:12,Exploration Rate:0.59
# Game Episode :108/500, High Score:13,Exploration Rate:0.58
# Game Episode :109/500, High Score:17,Exploration Rate:0.58
# Game Episode :110/500, High Score:8,Exploration Rate:0.58
# Game Episode :111/500, High Score:8,Exploration Rate:0.58
# Game Episode :112/500, High Score:9,Exploration Rate:0.57
# Game Episode :113/500, High Score:9,Exploration Rate:0.57
# Game Episode :114/500, High Score:12,Exploration Rate:0.57
# Game Episode :115/500, High Score:28,Exploration Rate:0.56
# Game Episode :116/500, High Score:11,Exploration Rate:0.56
# Game Episode :117/500, High Score:22,Exploration Rate:0.56
# Game Episode :118/500, High Score:9,Exploration Rate:0.56
# Game Episode :119/500, High Score:12,Exploration Rate:0.55
# Game Episode :120/500, High Score:16,Exploration Rate:0.55
# Game Episode :121/500, High Score:9,Exploration Rate:0.55
# Game Episode :122/500, High Score:30,Exploration Rate:0.55
# Game Episode :123/500, High Score:29,Exploration Rate:0.54
# Game Episode :124/500, High Score:37,Exploration Rate:0.54
# Game Episode :125/500, High Score:43,Exploration Rate:0.54
# Game Episode :126/500, High Score:21,Exploration Rate:0.53
# Game Episode :127/500, High Score:45,Exploration Rate:0.53
# Game Episode :128/500, High Score:66,Exploration Rate:0.53
# Game Episode :129/500, High Score:29,Exploration Rate:0.53
# Game Episode :130/500, High Score:25,Exploration Rate:0.52
# Game Episode :131/500, High Score:32,Exploration Rate:0.52
# Game Episode :132/500, High Score:16,Exploration Rate:0.52
# Game Episode :133/500, High Score:29,Exploration Rate:0.52
# Game Episode :134/500, High Score:40,Exploration Rate:0.51
# Game Episode :135/500, High Score:50,Exploration Rate:0.51
# Game Episode :136/500, High Score:96,Exploration Rate:0.51
# Game Episode :137/500, High Score:43,Exploration Rate:0.51
# Game Episode :138/500, High Score:49,Exploration Rate:0.5
# Game Episode :139/500, High Score:13,Exploration Rate:0.5
# Game Episode :140/500, High Score:34,Exploration Rate:0.5
# Game Episode :141/500, High Score:36,Exploration Rate:0.5
# Game Episode :142/500, High Score:24,Exploration Rate:0.49
# Game Episode :143/500, High Score:38,Exploration Rate:0.49
# Game Episode :144/500, High Score:34,Exploration Rate:0.49
# Game Episode :145/500, High Score:29,Exploration Rate:0.49
# Game Episode :146/500, High Score:27,Exploration Rate:0.48
# Game Episode :147/500, High Score:12,Exploration Rate:0.48
# Game Episode :148/500, High Score:12,Exploration Rate:0.48
# Game Episode :149/500, High Score:33,Exploration Rate:0.48
# Game Episode :150/500, High Score:65,Exploration Rate:0.47
# Game Episode :151/500, High Score:69,Exploration Rate:0.47
# Game Episode :152/500, High Score:35,Exploration Rate:0.47
# Game Episode :153/500, High Score:15,Exploration Rate:0.47
# Game Episode :154/500, High Score:27,Exploration Rate:0.46
# Game Episode :155/500, High Score:70,Exploration Rate:0.46
# Game Episode :156/500, High Score:28,Exploration Rate:0.46
# Game Episode :157/500, High Score:76,Exploration Rate:0.46
# Game Episode :158/500, High Score:68,Exploration Rate:0.46
# Game Episode :159/500, High Score:92,Exploration Rate:0.45
# Game Episode :160/500, High Score:78,Exploration Rate:0.45
# Game Episode :161/500, High Score:53,Exploration Rate:0.45
# Game Episode :162/500, High Score:31,Exploration Rate:0.45
# Game Episode :163/500, High Score:43,Exploration Rate:0.44
# Game Episode :164/500, High Score:25,Exploration Rate:0.44
# Game Episode :165/500, High Score:33,Exploration Rate:0.44
# Game Episode :166/500, High Score:14,Exploration Rate:0.44
# Game Episode :167/500, High Score:53,Exploration Rate:0.44
# Game Episode :168/500, High Score:32,Exploration Rate:0.43
# Game Episode :169/500, High Score:33,Exploration Rate:0.43
# Game Episode :170/500, High Score:28,Exploration Rate:0.43
# Game Episode :171/500, High Score:34,Exploration Rate:0.43
# Game Episode :172/500, High Score:32,Exploration Rate:0.42
# Game Episode :173/500, High Score:58,Exploration Rate:0.42
# Game Episode :174/500, High Score:40,Exploration Rate:0.42
# Game Episode :175/500, High Score:66,Exploration Rate:0.42
# Game Episode :176/500, High Score:34,Exploration Rate:0.42
# Game Episode :177/500, High Score:89,Exploration Rate:0.41
# Game Episode :178/500, High Score:56,Exploration Rate:0.41
# Game Episode :179/500, High Score:32,Exploration Rate:0.41
# Game Episode :180/500, High Score:21,Exploration Rate:0.41
# Game Episode :181/500, High Score:33,Exploration Rate:0.41
# Game Episode :182/500, High Score:149,Exploration Rate:0.4
# Game Episode :183/500, High Score:40,Exploration Rate:0.4
# Game Episode :184/500, High Score:54,Exploration Rate:0.4
# Game Episode :185/500, High Score:45,Exploration Rate:0.4
# Game Episode :186/500, High Score:59,Exploration Rate:0.4
# Game Episode :187/500, High Score:100,Exploration Rate:0.39
# Game Episode :188/500, High Score:66,Exploration Rate:0.39
# Game Episode :189/500, High Score:188,Exploration Rate:0.39
# Game Episode :190/500, High Score:27,Exploration Rate:0.39
# Game Episode :191/500, High Score:77,Exploration Rate:0.39
# Game Episode :192/500, High Score:53,Exploration Rate:0.38
# Game Episode :193/500, High Score:27,Exploration Rate:0.38
# Game Episode :194/500, High Score:44,Exploration Rate:0.38
# Game Episode :195/500, High Score:47,Exploration Rate:0.38
# Game Episode :196/500, High Score:48,Exploration Rate:0.38
# Game Episode :197/500, High Score:35,Exploration Rate:0.37
# Game Episode :198/500, High Score:82,Exploration Rate:0.37
# Game Episode :199/500, High Score:72,Exploration Rate:0.37
# Game Episode :200/500, High Score:39,Exploration Rate:0.37
# Game Episode :201/500, High Score:23,Exploration Rate:0.37
# Game Episode :202/500, High Score:34,Exploration Rate:0.37
# Game Episode :203/500, High Score:52,Exploration Rate:0.36
# Game Episode :204/500, High Score:57,Exploration Rate:0.36
# Game Episode :205/500, High Score:58,Exploration Rate:0.36
# Game Episode :206/500, High Score:53,Exploration Rate:0.36
# Game Episode :207/500, High Score:107,Exploration Rate:0.36
# Game Episode :208/500, High Score:59,Exploration Rate:0.35
# Game Episode :209/500, High Score:171,Exploration Rate:0.35
# Game Episode :210/500, High Score:34,Exploration Rate:0.35
# Game Episode :211/500, High Score:69,Exploration Rate:0.35
# Game Episode :212/500, High Score:25,Exploration Rate:0.35
# Game Episode :213/500, High Score:35,Exploration Rate:0.35
# Game Episode :214/500, High Score:43,Exploration Rate:0.34
# Game Episode :215/500, High Score:125,Exploration Rate:0.34
# Game Episode :216/500, High Score:38,Exploration Rate:0.34
# Game Episode :217/500, High Score:59,Exploration Rate:0.34
# Game Episode :218/500, High Score:77,Exploration Rate:0.34
# Game Episode :219/500, High Score:38,Exploration Rate:0.34
# Game Episode :220/500, High Score:51,Exploration Rate:0.33
# Game Episode :221/500, High Score:66,Exploration Rate:0.33
# Game Episode :222/500, High Score:95,Exploration Rate:0.33
# Game Episode :223/500, High Score:102,Exploration Rate:0.33
# Game Episode :224/500, High Score:79,Exploration Rate:0.33
# Game Episode :225/500, High Score:124,Exploration Rate:0.33
# Game Episode :226/500, High Score:92,Exploration Rate:0.32
# Game Episode :227/500, High Score:86,Exploration Rate:0.32
# Game Episode :228/500, High Score:75,Exploration Rate:0.32
# Game Episode :229/500, High Score:47,Exploration Rate:0.32
# Game Episode :230/500, High Score:103,Exploration Rate:0.32
# Game Episode :231/500, High Score:19,Exploration Rate:0.32
# Game Episode :232/500, High Score:111,Exploration Rate:0.31
# Game Episode :233/500, High Score:98,Exploration Rate:0.31
# Game Episode :234/500, High Score:104,Exploration Rate:0.31
# Game Episode :235/500, High Score:34,Exploration Rate:0.31
# Game Episode :236/500, High Score:145,Exploration Rate:0.31
# Game Episode :237/500, High Score:156,Exploration Rate:0.31
# Game Episode :238/500, High Score:79,Exploration Rate:0.3
# Game Episode :239/500, High Score:87,Exploration Rate:0.3
# Game Episode :240/500, High Score:137,Exploration Rate:0.3
# Game Episode :241/500, High Score:199,Exploration Rate:0.3
# Game Episode :242/500, High Score:125,Exploration Rate:0.3
# Game Episode :243/500, High Score:42,Exploration Rate:0.3
# Game Episode :244/500, High Score:70,Exploration Rate:0.3
# Game Episode :245/500, High Score:114,Exploration Rate:0.29
# Game Episode :246/500, High Score:111,Exploration Rate:0.29
# Game Episode :247/500, High Score:137,Exploration Rate:0.29
# Game Episode :248/500, High Score:109,Exploration Rate:0.29
# Game Episode :249/500, High Score:131,Exploration Rate:0.29
# Game Episode :250/500, High Score:135,Exploration Rate:0.29
# Game Episode :251/500, High Score:114,Exploration Rate:0.29
# Game Episode :252/500, High Score:155,Exploration Rate:0.28
# Game Episode :253/500, High Score:150,Exploration Rate:0.28
# Game Episode :254/500, High Score:102,Exploration Rate:0.28
# Game Episode :255/500, High Score:94,Exploration Rate:0.28
# Game Episode :256/500, High Score:199,Exploration Rate:0.28
# Game Episode :257/500, High Score:104,Exploration Rate:0.28
# Game Episode :258/500, High Score:174,Exploration Rate:0.28
# Game Episode :259/500, High Score:154,Exploration Rate:0.27
# Game Episode :260/500, High Score:129,Exploration Rate:0.27
# Game Episode :261/500, High Score:149,Exploration Rate:0.27
# Game Episode :262/500, High Score:141,Exploration Rate:0.27
# Game Episode :263/500, High Score:137,Exploration Rate:0.27
# Game Episode :264/500, High Score:143,Exploration Rate:0.27
# Game Episode :265/500, High Score:95,Exploration Rate:0.27
# Game Episode :266/500, High Score:57,Exploration Rate:0.26
# Game Episode :267/500, High Score:144,Exploration Rate:0.26
# Game Episode :268/500, High Score:87,Exploration Rate:0.26
# Game Episode :269/500, High Score:90,Exploration Rate:0.26
# Game Episode :270/500, High Score:79,Exploration Rate:0.26
# Game Episode :271/500, High Score:74,Exploration Rate:0.26
# Game Episode :272/500, High Score:98,Exploration Rate:0.26
# Game Episode :273/500, High Score:199,Exploration Rate:0.26
# Game Episode :274/500, High Score:26,Exploration Rate:0.25
# Game Episode :275/500, High Score:45,Exploration Rate:0.25
# Game Episode :276/500, High Score:34,Exploration Rate:0.25
# Game Episode :277/500, High Score:99,Exploration Rate:0.25
# Game Episode :278/500, High Score:96,Exploration Rate:0.25
# Game Episode :279/500, High Score:131,Exploration Rate:0.25
# Game Episode :280/500, High Score:55,Exploration Rate:0.25
# Game Episode :281/500, High Score:63,Exploration Rate:0.25
# Game Episode :282/500, High Score:113,Exploration Rate:0.24
# Game Episode :283/500, High Score:132,Exploration Rate:0.24
# Game Episode :284/500, High Score:131,Exploration Rate:0.24
# Game Episode :285/500, High Score:27,Exploration Rate:0.24
# Game Episode :286/500, High Score:53,Exploration Rate:0.24
# Game Episode :287/500, High Score:67,Exploration Rate:0.24
# Game Episode :288/500, High Score:75,Exploration Rate:0.24
# Game Episode :289/500, High Score:70,Exploration Rate:0.24
# Game Episode :290/500, High Score:50,Exploration Rate:0.23
# Game Episode :291/500, High Score:47,Exploration Rate:0.23
# Game Episode :292/500, High Score:139,Exploration Rate:0.23
# Game Episode :293/500, High Score:80,Exploration Rate:0.23
# Game Episode :294/500, High Score:132,Exploration Rate:0.23
# Game Episode :295/500, High Score:75,Exploration Rate:0.23
# Game Episode :296/500, High Score:101,Exploration Rate:0.23
# Game Episode :297/500, High Score:62,Exploration Rate:0.23
# Game Episode :298/500, High Score:83,Exploration Rate:0.23
# Game Episode :299/500, High Score:69,Exploration Rate:0.22
# Game Episode :300/500, High Score:115,Exploration Rate:0.22
# Game Episode :301/500, High Score:113,Exploration Rate:0.22
# Game Episode :302/500, High Score:116,Exploration Rate:0.22
# Game Episode :303/500, High Score:61,Exploration Rate:0.22
# Game Episode :304/500, High Score:90,Exploration Rate:0.22
# Game Episode :305/500, High Score:155,Exploration Rate:0.22
# Game Episode :306/500, High Score:119,Exploration Rate:0.22
# Game Episode :307/500, High Score:90,Exploration Rate:0.22
# Game Episode :308/500, High Score:199,Exploration Rate:0.21
# Game Episode :309/500, High Score:164,Exploration Rate:0.21
# Game Episode :310/500, High Score:125,Exploration Rate:0.21
# Game Episode :311/500, High Score:103,Exploration Rate:0.21
# Game Episode :312/500, High Score:162,Exploration Rate:0.21
# Game Episode :313/500, High Score:199,Exploration Rate:0.21
# Game Episode :314/500, High Score:124,Exploration Rate:0.21
# Game Episode :315/500, High Score:103,Exploration Rate:0.21
# Game Episode :316/500, High Score:140,Exploration Rate:0.21
# Game Episode :317/500, High Score:112,Exploration Rate:0.21
# Game Episode :318/500, High Score:156,Exploration Rate:0.2
# Game Episode :319/500, High Score:185,Exploration Rate:0.2
# Game Episode :320/500, High Score:124,Exploration Rate:0.2
# Game Episode :321/500, High Score:110,Exploration Rate:0.2
# Game Episode :322/500, High Score:119,Exploration Rate:0.2
# Game Episode :323/500, High Score:128,Exploration Rate:0.2
# Game Episode :324/500, High Score:128,Exploration Rate:0.2
# Game Episode :325/500, High Score:113,Exploration Rate:0.2
# Game Episode :326/500, High Score:102,Exploration Rate:0.2
# Game Episode :327/500, High Score:95,Exploration Rate:0.2
# Game Episode :328/500, High Score:129,Exploration Rate:0.19
